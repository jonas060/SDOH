# %%
import pandas

# %%
cities = pandas.read_csv("Data/500_Cities__Local_Data_for_Better_Health__2019_release_20240314.zip")
SVI = pandas.read_csv("Data/SVI_2020_US_county.csv")

# %%
SVI.head(5)
# Out:
#    ST    STATE ST_ABBR  STCNTY   COUNTY  FIPS                 LOCATION  \
# 0   1  Alabama      AL    1001  Autauga  1001  Autauga County, Alabama
# 1   1  Alabama      AL    1003  Baldwin  1003  Baldwin County, Alabama
# 2   1  Alabama      AL    1005  Barbour  1005  Barbour County, Alabama
# 3   1  Alabama      AL    1007     Bibb  1007     Bibb County, Alabama
# 4   1  Alabama      AL    1009   Blount  1009   Blount County, Alabama
#
#      AREA_SQMI  E_TOTPOP  M_TOTPOP  ...  EP_ASIAN  MP_ASIAN  EP_AIAN  MP_AIAN  \
# 0   594.455838     55639         0  ...       1.2       0.3      0.3      0.2
# 1  1589.835294    218289         0  ...       0.9       0.2      0.6      0.2
# 2   885.007618     25026         0  ...       0.5       0.1      0.3      0.3
# 3   622.469288     22374         0  ...       0.3       0.4      0.1      0.1
# 4   644.890375     57755         0  ...       0.4       0.1      0.1      0.1
#
# ...

# %%
cities.head(5)
# Out:
#    Year StateAbbr   StateDesc   CityName GeographicLevel DataSource  \
# 0  2017        CA  California  Hawthorne    Census Tract      BRFSS
# 1  2017        CA  California  Hawthorne            City      BRFSS
# 2  2017        CA  California    Hayward            City      BRFSS
# 3  2017        CA  California    Hayward            City      BRFSS
# 4  2017        CA  California      Hemet            City      BRFSS
#
#               Category             UniqueID  \
# 0      Health Outcomes  0632548-06037602504
# 1  Unhealthy Behaviors              0632548
# 2      Health Outcomes              0633000
# 3  Unhealthy Behaviors              0633000
# 4           Prevention              0633182
#
#                                              Measure Data_Value_Unit  ...  \
# 0             Arthritis among adults aged >=18 Years               %  ...
# 1       Current smoking among adults aged >=18 Years               %  ...
# ...

# %%
cities.Year.unique()
# Out:
# array([2017, 2016])

# %%
list(cities.columns)
# Out:
# ['Year',
#  'StateAbbr',
#  'StateDesc',
#  'CityName',
#  'GeographicLevel',
#  'DataSource',
#  'Category',
#  'UniqueID',
#  'Measure',
#  'Data_Value_Unit',
#  'DataValueTypeID',
#  'Data_Value_Type',
#  'Data_Value',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit',
#  'Data_Value_Footnote_Symbol',
#  'Data_Value_Footnote',
#  'PopulationCount',
#  'GeoLocation',
#  'CategoryID',
#  'MeasureId',
#  'CityFIPS',
#  'TractFIPS',
#  'Short_Question_Text']

# %%
cities.loc[1:5,['Measure',
 'Data_Value_Unit',
 'DataValueTypeID',
 'Data_Value_Type',
 'Data_Value',
 'Low_Confidence_Limit',
 'High_Confidence_Limit']]
# Out:
#                                              Measure Data_Value_Unit  \
# 1       Current smoking among adults aged >=18 Years               %
# 2  Coronary heart disease among adults aged >=18 ...               %
# 3               Obesity among adults aged >=18 Years               %
# 4  Cholesterol screening among adults aged >=18 Y...               %
# 5             Arthritis among adults aged >=18 Years               %
#
#   DataValueTypeID          Data_Value_Type  Data_Value  Low_Confidence_Limit  \
# 1          CrdPrv         Crude prevalence        15.4                  15.0
# 2       AgeAdjPrv  Age-adjusted prevalence         4.8                   4.7
# 3          CrdPrv         Crude prevalence        24.2                  24.1
# 4       AgeAdjPrv  Age-adjusted prevalence        78.0                  77.6
# 5          CrdPrv         Crude prevalence        22.0                  21.1
#
#    High_Confidence_Limit
# 1                   15.9
# 2                    4.8
# ...

# %%
#Retrieve Health Outcome Data
Health_Outcomes = cities.loc[cities['Category'] == "Health Outcomes"]

#Retrieve Cornorary Heart Disease Data
Heart_Disease = Health_Outcomes.loc[Health_Outcomes['Measure'] == "Coronary heart disease among adults aged >=18 Years"]

# %%
Health_Outcomes.Measure.unique()
# Out:
# array(['Arthritis among adults aged >=18 Years',
#        'Coronary heart disease among adults aged >=18 Years',
#        'Chronic obstructive pulmonary disease among adults aged >=18 Years',
#        'Diagnosed diabetes among adults aged >=18 Years',
#        'All teeth lost among adults aged >=65 Years',
#        'Current asthma among adults aged >=18 Years',
#        'Chronic kidney disease among adults aged >=18 Years',
#        'Stroke among adults aged >=18 Years',
#        'High blood pressure among adults aged >=18 Years',
#        'Cancer (excluding skin cancer) among adults aged >=18 Years',
#        'Physical health not good for >=14 days among adults aged >=18 Years',
#        'Mental health not good for >=14 days among adults aged >=18 Years',
#        'High cholesterol among adults aged >=18 Years who have been screened in the past 5 Years'],
#       dtype=object)

# %%
#All datarows containing High_Confidence_Limit above >10% for Coronary Heart Disease.
Heart_Disease_above_10 = Heart_Disease.loc[Heart_Disease['High_Confidence_Limit'] > 10]

# %%
#Cities in Minnesota with Coronary Heart Disease above >10%
Heart_Disease_above_10.loc[Heart_Disease_above_10['StateAbbr'] == "MN"]
# Out:
#         Year StateAbbr  StateDesc     CityName GeographicLevel DataSource  \
# 423285  2017        MN  Minnesota       Duluth    Census Tract      BRFSS
# 428572  2017        MN  Minnesota  Minneapolis    Census Tract      BRFSS
# 435505  2017        MN  Minnesota    Rochester    Census Tract      BRFSS
#
#                Category             UniqueID  \
# 423285  Health Outcomes  2717000-27137001900
# 428572  Health Outcomes  2743000-27053005901
# 435505  Health Outcomes  2754880-27109000100
#
#                                                   Measure Data_Value_Unit  \
# 423285  Coronary heart disease among adults aged >=18 ...               %
# 428572  Coronary heart disease among adults aged >=18 ...               %
# 435505  Coronary heart disease among adults aged >=18 ...               %
#
#         ... High_Confidence_Limit Data_Value_Footnote_Symbol  \
# 423285  ...                  13.2                        NaN
# ...
